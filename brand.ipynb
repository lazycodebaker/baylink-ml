# %%
import pandas as pd 
import matplotlib.pyplot as plt 
import seaborn as sns
import numpy as np

brands = pd.read_json('brand_data.json')

brands
# Out:
#                                  Brand_ID  Funding_Amount  Brand_Age  \
# 0    9f5eb704-4cf8-4f88-9d3b-210a74188ac6         3807099          5
# 1    61354027-e603-4992-9cb7-66444bdac868         7139508          6
# 2    71d02b32-7617-4a19-a3d8-fd8d650dfcf0         8862546          1
# 3    a6a4782f-851a-4bb7-b04e-23a002367569         1590777          4
# 4    85130f78-7050-4f3c-a70e-a0972a65f151         1149691          9
# ..                                    ...             ...        ...
# 995  650916f4-7450-492f-bdd7-1dd3f857691c         3679537          5
# 996  2d5137ab-3fe5-41ad-866e-d00dce49a124         5087579         10
# 997  150b9f3c-68de-4cb4-83d9-c003a6195db4          171517          4
# 998  b12bdc75-cdfc-4f9e-aa1c-78fc58f1f302         3792694         10
# 999  cfd7ada2-699e-404f-a183-21a15492a616         8819340          2
#
#      Revenue_Last_Month      ARR Target_Audience Headquarters_Location  \
# 0               1245928  6506304         Seniors           Josephburgh
# 1               1592520  7164143             All        Frederickhaven
# 2               3765423  5274341             All              Grayfurt
# 3               5545234  6713265             All          Aprilchester
# 4               1546770  5674107             All        Port Joelmouth
# ..                  ...      ...             ...                   ...
# 995             5120117   153746         Seniors          North Krista
# 996             3151539  9872327         Seniors          Delacruzport
# 997             2453053  3013885           Teens     South Jessicastad
# 998             2805061  9108106             All          Patriciastad
# 999             7420576  3337391         Seniors         Port Patricia
#
#      Number_of_Employees Product_Category               Product_Sub_Category  \
# 0                   4357           Others  Bakery and confectionary products
# 1                   7767           Others                           Pet Food
# 2                     27        Beverages                 Snacks and namkeen
# 3                   6315           Others                     Nutraceuticals
# 4                   6867             Food       Carbonated and Energy Drinks
# ..                   ...              ...                                ...
# 995                 2118           Others               Milk based beverages
# 996                 2839             Food         Pickles, Jams and Ketchups
# 997                 2640           Others           RTE & Instant Food mixes
# 998                 8917             Food               Milk based beverages
# 999                 1381           Others                 Snacks and namkeen
#
#      ... Social_Media_Presence  Consumer_Engagement_Programs  \
# 0    ...                  High                          True
# 1    ...                Medium                          True
# 2    ...                Medium                         False
# 3    ...                   Low                          True
# 4    ...                  High                         False
# ..   ...                   ...                           ...
# 995  ...                  High                          True
# 996  ...                   Low                          True
# 997  ...                  High                          True
# 998  ...                Medium                          True
# 999  ...                   Low                         False
#
#     Brand_Collaborations  Advertising_Channels  Certifications_Awards  \
# 0                   True                 Print             Fair Trade
# 1                   True          Social Media                Organic
# 2                   True          Social Media                Organic
# 3                   True            Online Ads                Organic
# 4                  False          Social Media             Fair Trade
# ..                   ...                   ...                    ...
# 995                 True                 Print                   None
# 996                False                 Print                Organic
# 997                 True          Social Media             Fair Trade
# 998                False                 Print             Fair Trade
# 999                False            Online Ads                Organic
#
#                    Company_Website Customer_Reviews_Ratings  \
# 0              http://simmons.com/                 1.641481
# 1         https://www.woodard.biz/                 1.501957
# 2       http://gordon-johnson.biz/                 4.908490
# 3          https://www.thomas.com/                 3.374297
# 4    http://www.martin-hansen.com/                 4.474484
# ..                             ...                      ...
# 995    https://www.hutchinson.biz/                 0.419270
# 996      https://www.robinson.com/                 4.340929
# 997             https://wood.info/                 4.154787
# 998  https://www.smith-warren.com/                 4.093903
# 999             http://butler.com/                 1.474087
#
#     Compliance_with_Regulations Product_Pipeline  Customer_Support_Services
# 0                          True               No                      Phone
# 1                         False              Yes                      Phone
# 2                          True              Yes                      Email
# 3                          True               No                Online Chat
# 4                         False              Yes                      Phone
# ..                          ...              ...                        ...
# 995                        True              Yes                      Phone
# 996                        True               No                      Email
# 997                        True               No                      Phone
# 998                       False              Yes                      Email
# 999                        True              Yes                      Email
#
# [1000 rows x 39 columns]

# %%
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error
import numpy as np
import pandas as pd
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error
import numpy as np

# %%
brands
# Out:
#                                  Brand_ID  Funding_Amount  Brand_Age  \
# 0    9f5eb704-4cf8-4f88-9d3b-210a74188ac6         3807099          5
# 1    61354027-e603-4992-9cb7-66444bdac868         7139508          6
# 2    71d02b32-7617-4a19-a3d8-fd8d650dfcf0         8862546          1
# 3    a6a4782f-851a-4bb7-b04e-23a002367569         1590777          4
# 4    85130f78-7050-4f3c-a70e-a0972a65f151         1149691          9
# ..                                    ...             ...        ...
# 995  650916f4-7450-492f-bdd7-1dd3f857691c         3679537          5
# 996  2d5137ab-3fe5-41ad-866e-d00dce49a124         5087579         10
# 997  150b9f3c-68de-4cb4-83d9-c003a6195db4          171517          4
# 998  b12bdc75-cdfc-4f9e-aa1c-78fc58f1f302         3792694         10
# 999  cfd7ada2-699e-404f-a183-21a15492a616         8819340          2
#
#      Revenue_Last_Month      ARR Target_Audience Headquarters_Location  \
# 0               1245928  6506304         Seniors           Josephburgh
# 1               1592520  7164143             All        Frederickhaven
# 2               3765423  5274341             All              Grayfurt
# 3               5545234  6713265             All          Aprilchester
# 4               1546770  5674107             All        Port Joelmouth
# ..                  ...      ...             ...                   ...
# 995             5120117   153746         Seniors          North Krista
# 996             3151539  9872327         Seniors          Delacruzport
# 997             2453053  3013885           Teens     South Jessicastad
# 998             2805061  9108106             All          Patriciastad
# 999             7420576  3337391         Seniors         Port Patricia
#
#      Number_of_Employees Product_Category               Product_Sub_Category  \
# 0                   4357           Others  Bakery and confectionary products
# 1                   7767           Others                           Pet Food
# 2                     27        Beverages                 Snacks and namkeen
# 3                   6315           Others                     Nutraceuticals
# 4                   6867             Food       Carbonated and Energy Drinks
# ..                   ...              ...                                ...
# 995                 2118           Others               Milk based beverages
# 996                 2839             Food         Pickles, Jams and Ketchups
# 997                 2640           Others           RTE & Instant Food mixes
# 998                 8917             Food               Milk based beverages
# 999                 1381           Others                 Snacks and namkeen
#
#      ... Social_Media_Presence  Consumer_Engagement_Programs  \
# 0    ...                  High                          True
# 1    ...                Medium                          True
# 2    ...                Medium                         False
# 3    ...                   Low                          True
# 4    ...                  High                         False
# ..   ...                   ...                           ...
# 995  ...                  High                          True
# 996  ...                   Low                          True
# 997  ...                  High                          True
# 998  ...                Medium                          True
# 999  ...                   Low                         False
#
#     Brand_Collaborations  Advertising_Channels  Certifications_Awards  \
# 0                   True                 Print             Fair Trade
# 1                   True          Social Media                Organic
# 2                   True          Social Media                Organic
# 3                   True            Online Ads                Organic
# 4                  False          Social Media             Fair Trade
# ..                   ...                   ...                    ...
# 995                 True                 Print                   None
# 996                False                 Print                Organic
# 997                 True          Social Media             Fair Trade
# 998                False                 Print             Fair Trade
# 999                False            Online Ads                Organic
#
#                    Company_Website Customer_Reviews_Ratings  \
# 0              http://simmons.com/                 1.641481
# 1         https://www.woodard.biz/                 1.501957
# 2       http://gordon-johnson.biz/                 4.908490
# 3          https://www.thomas.com/                 3.374297
# 4    http://www.martin-hansen.com/                 4.474484
# ..                             ...                      ...
# 995    https://www.hutchinson.biz/                 0.419270
# 996      https://www.robinson.com/                 4.340929
# 997             https://wood.info/                 4.154787
# 998  https://www.smith-warren.com/                 4.093903
# 999             http://butler.com/                 1.474087
#
#     Compliance_with_Regulations Product_Pipeline  Customer_Support_Services
# 0                          True               No                      Phone
# 1                         False              Yes                      Phone
# 2                          True              Yes                      Email
# 3                          True               No                Online Chat
# 4                         False              Yes                      Phone
# ..                          ...              ...                        ...
# 995                        True              Yes                      Phone
# 996                        True               No                      Email
# 997                        True               No                      Phone
# 998                       False              Yes                      Email
# 999                        True              Yes                      Email
#
# [1000 rows x 39 columns]
